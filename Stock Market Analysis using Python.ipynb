# %%
# To install yfinance package run:

pip install yfinance
# Out:
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=c37d4c73d8a6f27f546f35994b1fe64318feedfc05f9ece3b2235f48c3c95f77
#   Stored in directory: /Users/hyma/Library/Caches/pip/wheels/f2/b5/2c/59ba95dcf854e542944c75fe3da584e4e3833b319735a0546c
# Successfully built multitasking
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Lets import yfinance as yf and create a ticker object for a Tesla stock.

import yfinance as yf

TSLA= yf.Ticker("TSLA")

TSLA
# Out:
# yfinance.Ticker object <TSLA>

# %%
# Lets pull daily stock prices for Tesla(TSLA)

data = yf.download("TSLA", start="2019-01-01", end="2022-04-30", interval="1d")

data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2018-12-31    67.557999    67.842003   65.052002    66.559998    66.559998
# 2019-01-02    61.220001    63.026001   59.759998    62.023998    62.023998
# 2019-01-03    61.400002    61.880001   59.476002    60.071999    60.071999
# 2019-01-04    61.200001    63.599998   60.546001    63.537998    63.537998
# 2019-01-07    64.344002    67.348000   63.549999    66.991997    66.991997
# ...                 ...          ...         ...          ...          ...
# 2022-04-22  1014.909973  1034.849976  994.000000  1005.049988  1005.049988
# 2022-04-25   978.969971  1008.619995  975.299988   998.020020   998.020020
# 2022-04-26   995.429993  1000.000000  875.000000   876.419983   876.419983
# 2022-04-27   898.580017   918.000000  877.359985   881.510010   881.510010
# ...

# %%
# Let's get price to earnings ratio

TSLA = yf.Ticker("TSLA")
TSLA.info['forwardPE']
# Out:
# 44.69836

# %%
# Current volume

TSLA.info["volume"]
# Out:
# 28883854

# %%
# Average volume over the last 24 hours:

TSLA.info["averageVolume"]
# Out:
# 26687481

# %%
# To get the weekly highs and lows for Tesla

data = yf.download("TSLA", period="max", interval="1wk")

data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open         High         Low       Close   Adj Close  \
# Date
# 2010-06-28    3.800000     6.084000    3.508000    3.840000    3.840000
# 2010-07-05    4.000000     4.000000    2.996000    3.480000    3.480000
# 2010-07-12    3.590000     4.300000    3.380000    4.128000    4.128000
# 2010-07-19    4.274000     4.450000    3.900000    4.258000    4.258000
# 2010-07-26    4.300000     4.300000    3.910000    3.988000    3.988000
# ...                ...          ...         ...         ...         ...
# 2022-04-25  978.969971  1008.619995  821.700012  870.760010  870.760010
# 2022-05-02  860.770020   955.500000  843.109985  865.650024  865.650024
# 2022-05-09  836.450012   845.630005  680.000000  769.590027  769.590027
# 2022-05-16  767.159973   769.760010  700.809998  709.809998  709.809998
# 2022-05-18  744.520020   760.500000  700.809998  709.809998  709.809998
#
#                  Volume
# ...

# %%
conda install -c quantopian ta-lib
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - ta-lib -> python[version='2.7.*|3.4.*|>=2.7,<2.8.0a0|>=3.5,<3.6.0a0|3.3.*']
#   - ta-lib -> python[version='>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.8,<3.9.0a0']
#
# Your python: python=3.9
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# ...

# %%
# Lets plot an OHLC chart (Open, High, Low, Close prices). We are going to use the Plotly library for the OHLC chart.

pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# OHLC chart for Tesla stock.


import plotly.graph_objects as go

fig = go.Figure(
    data=go.Ohlc(
        x=data.index,
        open=data["Open"],
        high=data["High"],
        low=data["Low"],
        close=data["Close"],
     )
)

fig.update_layout(
     xaxis_title="OHLC chart with Tesla Stock prices"

)  


fig.show()
# Out:
# <div>                            <div id="986a5d21-8f63-4a74-903e-058b3958e367" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("986a5d21-8f63-4a74-903e-058b3958e367")) {                    Plotly.newPlot(                        "986a5d21-8f63-4a74-903e-058b3958e367",                        [{"close":[3.8399999141693115,3.4800000190734863,4.127999782562256,4.257999897003174,3.98799991607666,3.9179999828338623,3.6640000343322754,3.819999933242798,3.940000057220459,4.210000038146973,4.033999919891357,4.046000003814697,4.019999980926514,4.119999885559082,4.085999965667725,4.107999801635742,4.144000053405762,4.368000030517578,4.888000011444092,5.9679999351501465,6.197999954223633,7.064000129699707,6.297999858856201,6.303999900817871,6.271999835968018,6.0
# ...

# %%
# Import matplotlib for plotting

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Plot adjusted close price data

data['Adj Close'].plot(figsize=(10, 7))

plt.title("Adjusted Close Price of Tesla", fontsize=16)

plt.ylabel('Price', fontsize=14)

plt.xlabel('Year', fontsize=14)

plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

plt.show()

# %%
# Historical view of the total volume of Tesla stock traded each day

data['Volume'].plot(legend=True,figsize=(10,4))

plt.title("Volume of Tesla Stock Traded Each Day", fontsize=16)

plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

plt.show()

# %%
# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
#Calculation to find he percent change for each day of Tesla stock

data['Daily Return'] = data['Adj Close'].pct_change()

# %%
# Visualization of the percent change for each day of Tesla stock

data['Daily Return'].plot(figsize=(12,4),legend=True,linestyle='--',marker='o')
# Out:
# <AxesSubplot:xlabel='Date'>
